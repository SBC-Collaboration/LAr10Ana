# %%
from GetEvent import GetEvent
from BF_20260219 import GetBubDict
# Out:
# DIPlib -- a quantitative image analysis library
# Version 3.6.0 (Oct 23 2025)
# For more information see https://diplib.org

# %%
ll = ['cam','run_control']

TEST_RUN = '/exp/e961/app/users/alkucich/LAr10Ana/nb/MyAna/HoughStough/Data/20260217_9'
TEST_EVT = 21

ev = GetEvent(TEST_RUN, TEST_EVT,*ll)

# %%
# %%time
ev_dict = GetBubDict(ev)
# Out:
# CPU times: user 13.4 s, sys: 255 ms, total: 13.7 s
# Wall time: 10.5 s

# %%
ev_dict
# Out:
# {'Bubble0': {'Pos': (np.int64(496), np.int64(353)),
#   'Radius': np.int64(4),
#   'Significance': 1.0,
#   'Frame': 29,
#   'Camera': 1},
#  'Bubble1': {'Pos': (np.int64(496), np.int64(353)),
#   'Radius': np.int64(4),
#   'Significance': 1.0,
#   'Frame': 28,
#   'Camera': 1},
#  'Bubble2': {'Pos': (np.int64(496), np.int64(353)),
#   'Radius': np.int64(4),
#   'Significance': 1.0,
#   'Frame': 27,
#   'Camera': 1},
#  'Bubble3': {'Pos': (np.int64(496), np.int64(353)),
#   'Radius': np.int64(5),
#   'Significance': np.float64(1.0),
#   'Frame': 30,
#   'Camera': 1},
#  'Bubble4': {'Pos': (np.int64(498), np.int64(352)),
#   'Radius': np.int64(5),
#   'Significance': np.float64(1.0),
#   'Frame': 31,
#   'Camera': 1},
#  'Bubble5': {'Pos': (np.int64(498), np.int64(353)),
#   'Radius': np.int64(4),
#   'Significance': np.float64(1.0),
#   'Frame': 32,
#   'Camera': 1},
#  'Bubble6': {'Pos': (np.int64(498), np.int64(353)),
#   'Radius': np.float64(9.0),
# ...

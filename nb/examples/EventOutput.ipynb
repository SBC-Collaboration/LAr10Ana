# %%
from sbcbinaryformat import Streamer, Writer
import numpy as np

from GetEvent import GetEvent

# %%
TEST_RUN = "/exp/e961/data/SBC-25-daqdata/20250611_1/"
TEST_EVT = 0

# %%
data = GetEvent(TEST_RUN, TEST_EVT)

# %%
data["event_info"]
# Out:
# {'loaded': True,
#  'run_id': array(['20250611_1'], dtype='<U100'),
#  'event_id': array([0], dtype=uint32),
#  'ev_exit_code': array([0], dtype=uint8),
#  'ev_livetime': array([11273], dtype=uint64),
#  'cum_livetime': array([11273], dtype=uint64),
#  'pset': array([2.], dtype=float32),
#  'pset_hi': array([2.2], dtype=float32),
#  'pset_slope': array([0.], dtype=float32),
#  'pset_period': array([-1.], dtype=float32),
#  'start_time': array([1.74965412e+09]),
#  'end_time': array([1.74965413e+09]),
#  'trigger_source': array(['Software'], dtype='<U100')}

# %%
data["slow_daq"]
# Out:
# {'loaded': True,
#  'time_ms': array([  140,   150,   160, ..., 23950, 23960, 23970],
#        shape=(2384,), dtype=uint32),
#  'valves': array([0, 0, 0, ..., 0, 0, 0], shape=(2384,), dtype=uint32),
#  'PT3308': array([1.3760984, 1.3887231, 1.3887231, ..., 1.3634737, 1.369786 ,
#         1.369786 ], shape=(2384,), dtype=float32),
#  'PT3309': array([0.9594815 , 0.9721062 , 0.9594815 , ..., 0.9594815 , 0.9594815 ,
#         0.95316905], shape=(2384,), dtype=float32),
#  'PT3311': array([1.4139726, 1.3950355, 1.4139726, ..., 1.3950355, 1.4013479,
#         1.4139726], shape=(2384,), dtype=float32),
#  'PT3314': array([38.06995 , 38.06995 , 38.06995 , ..., 38.00683 , 38.000515,
#         38.01314 ], shape=(2384,), dtype=float32),
#  'PT3320': array([-0.07797241, -0.0769043 , -0.07904053, ..., -0.09292603,
#         -0.09933472, -0.08758545], shape=(2384,), dtype=float32),
#  'PT3332': array([0.7827349 , 0.77011013, 0.77011013, ..., 0.8332339 , 0.7953596 ,
#         0.7953596 ], shape=(2384,), dtype=float32),
#  'PT3333': array([0.9973557 , 1.0036681 , 0.9973557 , ..., 0.9405443 , 0.9152948 ,
#         0.93423194], shape=(2384,), dtype=float32),
#  'CYL3334_FCALC': array([121.088615, 122.709114, 121.70203 , ..., 109.57119 , 107.38307 ,
#         110.40433 ], shape=(2384,), dtype=float32),
#  'LT3335': array([4.5396 , 4.54272, 4.53336, ..., 4.5474 , 4.53336, 4.5396 ],
#        shape=(2384,), dtype=float32),
#  'SERVO3321_OUT': array([0., 0., 0., ..., 0., 0., 0.], shape=(2384,), dtype=float32),
#  'SERVO3321_IN': array([0.08544922, 0.09155273, 0.08544922, ..., 0.07324219, 0.05493164,
#         0.06713867], shape=(2384,), dtype=float32)}

# %%
data["run_control"]["caen"]
# Out:
# {'global': {'enabled': True,
#   'data_path': '/mnt/nas/rc-data/current_event/',
#   'model': 'DT5740D',
#   'link': 0,
#   'connection': 'USB',
#   'evs_per_read': 500,
#   'rec_length': 200,
#   'post_trig': 50,
#   'trig_in_as_gate': False,
#   'decimation': 0,
#   'overlap_en': False,
#   'memory_full': 'One Buf Free',
#   'counting_mode': 'All',
#   'polarity': 'Falling',
#   'majority_level': 0,
#   'majority_window': 5,
#   'clock_source': 'Internal',
#   'acq_mode': 'SW CTRL',
#   'io_level': 'TTL',
#   'ext_trig': 'ACQ_ONLY',
#   'sw_trig': 'ACQ_ONLY',
#   'ch_trig': 'ACQ_ONLY'},
#  'group0': {'enabled': True,
#   'threshold': 2000,
#   'offset': 32768,
#   'range': '2 Vpp',
#   'name': ['1-01', '1-02', '1-03', '1-04', '1-05', '1-06', '1-07', '1-08'],
#   'trig_mask': [True, True, True, True, True, True, True, True],
#   'acq_mask': [True, True, True, True, True, True, True, True],
#   'plot_mask': [False, False, False, False, False, False, False, False],
#   'ch_offset': [0, 0, 0, 0, 0, 0, 0, 0]},
#  'group1': {'enabled': True,
#   'threshold': 2000,
#   'offset': 32768,
#   'range': '2 Vpp',
#   'name': ['1-09', '1-10', '1-11', '1-12', '1-13', '1-14', '1-15', '1-16'],
#   'trig_mask': [True, True, True, True, True, True, True, True],
#   'acq_mask': [True, True, True, True, True, True, True, True],
#   'plot_mask': [False, False, False, False, False, False, False, False],
#   'ch_offset': [0, 0, 0, 0, 0, 0, 0, 0]},
#  'group2': {'enabled': True,
#   'threshold': 2000,
#   'offset': 32768,
#   'range': '2 Vpp',
#   'name': ['2-01', '2-02', '2-03', '2-04', '2-05', '2-06', '2-07', '2-08'],
#   'trig_mask': [False, False, False, False, False, False, False, False],
#   'acq_mask': [True, True, True, True, True, True, True, True],
#   'plot_mask': [False, False, False, False, False, False, False, False],
#   'ch_offset': [0, 0, 0, 0, 0, 0, 0, 0]},
#  'group3': {'enabled': True,
#   'threshold': 2000,
#   'offset': 32768,
#   'range': '2 Vpp',
#   'name': ['2-09', '2-10', '2-11', '2-12', '2-13', '2-14', '2-15', '2-16'],
#   'trig_mask': [False, False, False, False, False, False, False, False],
#   'acq_mask': [True, True, True, True, True, True, True, True],
#   'plot_mask': [False, False, False, False, False, False, False, False],
#   'ch_offset': [0, 0, 0, 0, 0, 0, 0, 0]}}

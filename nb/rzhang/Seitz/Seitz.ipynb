# %%
import SeitzModel as sm
sm.SeitzModel(48, -273.15+116, 'argon').Q
# Out:
# 1.9997342373604723

# %%
pressure = [2.25,2.5,2.75,3,3.5,4,4.25,4.5]
temperature  =116
Seitz_keV = []

# %%
for i in pressure:
    setiz = sm.SeitzModel(i*14.50, -273.15+temperature, 'argon').Q
    Seitz_keV.append(setiz)
print(Seitz_keV)
# Out:
# [1.3445287166423177, 1.4677096307281403, 1.6077252261931916, 1.7676644948295235, 2.163478457894038, 2.698514892785409, 3.038557782566206, 3.44261366411884]

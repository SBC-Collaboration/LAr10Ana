# %%
import SeitzModel as sm
import numpy as np
sm.SeitzModel(48, -273.15+116, 'argon').Q
# Out:
# 1.9997342373604723

# %%
pressure = np.arange(2.25, 6.5, 0.25)

temperature  =116
Seitz_keV = []

# %%
for i in pressure:
    setiz = sm.SeitzModel(i*14.50, -273.15+temperature, 'argon').Q
    Seitz_keV.append(setiz)
print(Seitz_keV)
# Out:
# [np.float64(1.3445287166423177), np.float64(1.4677096307281403), np.float64(1.6077252261931916), np.float64(1.7676644948295235), np.float64(1.9513368144218666), np.float64(2.163478457894038), np.float64(2.41003021032974), np.float64(2.698514892785409), np.float64(3.038557782566206), np.float64(3.44261366411884), np.float64(3.9269986461894346), np.float64(4.513378617028501), np.float64(5.230956628311766), np.float64(6.119753114689943), np.float64(7.235636873731044), np.float64(8.658238672578), np.float64(10.503756197125261)]

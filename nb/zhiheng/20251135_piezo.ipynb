# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from sbcbinaryformat import Streamer, Writer

ana_path = "../LAr10Ana/"
sys.path.insert(0, ana_path)

from GetEvent import GetEvent

# %matplotlib inline

# %%
run = "/exp/e961/data/SBC-25-daqdata/20260112_2.tar"
event = 0
data = GetEvent(run, event, "acoustics", "slow_daq", "run_info", "event_info", strictMode=False, lazy_load_scintillation=False)
acous = data["acoustics"]
acous.keys()
# Out:
# dict_keys(['loaded', 'Range', 'DCOffset', 'Waveforms'])

# %%
plt.plot(acous["Waveforms"][0,5])
# plt.xlim(780000, 920000)
plt.show()

# %%
from sbcbinaryformat import Streamer, Writer
import numpy as np
import matplotlib.pyplot as plt

from GetEvent import GetEvent

# %%
run = "/exp/e961/data/SBC-25-daqdata/20251117_10"
event = 0
data = GetEvent(run, event, "scintillation", strictMode=False)
